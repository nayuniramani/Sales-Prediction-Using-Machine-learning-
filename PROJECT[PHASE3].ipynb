# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings # Ignores any warning
warnings.filterwarnings("ignore")
train = pd.read_csv("C:/Users/DELL/Desktop/Train.csv")
test = pd.read_csv("C:/Users/DELL/Desktop/Test.csv")

# %%
train['source']='train'
test['source']='test'

data = pd.concat([train,test], ignore_index = True)
print(train.shape, test.shape, data.shape)
# Out:
# (9523, 19) (6681, 18) (16204, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16204 entries, 0 to 16203
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Identifier_Of_Item         16204 non-null  object
#  1   Weight_Of_Item             13396 non-null  float64
#  2   Content_Of_Fat             16204 non-null  object
#  3   Visibility_Of_Item         16204 non-null  float64
#  4   Type_Of_Item               16204 non-null  object
#  5   MRP_Of_Item                16204 non-null  float64
#  6   Identifier_Of_Outlet       16204 non-null  object
#  7   Outlet_Establishment_Year  16204 non-null  int64
#  8   Store_Capacity             11637 non-null  object
#  9   Outlet_Location_Type       16204 non-null  object
#  10  Outlet_Type                16204 non-null  object
#  11  IsNewCust                  14763 non-null  object
#  12  IsSpecialDay               16144 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# Identifier_Of_Item              0
# Weight_Of_Item               2808
# Content_Of_Fat                  0
# Visibility_Of_Item              0
# Type_Of_Item                    0
# MRP_Of_Item                     0
# Identifier_Of_Outlet            0
# Outlet_Establishment_Year       0
# Store_Capacity               4567
# Outlet_Location_Type            0
# Outlet_Type                     0
# IsNewCust                    1441
# IsSpecialDay                   60
# Advertising_Of_Item           110
# Population_Density           1204
# Product_Packing                97
# Discount_Of_Item              739
# Item_Outlet_Sales            6681
# source                          0
# dtype: int64

# %%
data['Weight_Of_Item']=data['Weight_Of_Item'].fillna(data.groupby('Identifier_Of_Item')['Weight_Of_Item'].transform('mean'))

# %%
data.Weight_Of_Item.isnull().sum()
# Out:
# 0

# %%
#Import mode function:
from scipy.stats import mode

#Determing the mode for each
Store_Capacity_mode = data.pivot_table(values='Store_Capacity', columns='Outlet_Type',aggfunc=lambda x:x.mode())
Store_Capacity_mode
# Out:
# Outlet_Type    Grocery Store Supermarket Type1 Supermarket Type2  \
# Store_Capacity         Small             Small            Medium
#
# Outlet_Type    Supermarket Type3
# Store_Capacity            Medium

# %%
def impute_size_mode(cols):
    Size = cols[0]
    Type = cols[1]
    if pd.isnull(Size):
        return Store_Capacity_mode.loc['Store_Capacity'][Store_Capacity_mode.columns == Type][0]
    else:
        return Size

print ('Orignal #missing: %d'%sum(data['Store_Capacity'].isnull()))
data['Store_Capacity'] = data[['Store_Capacity','Outlet_Type']].apply(impute_size_mode,axis=1)
print ('Final #missing: %d'%sum(data['Store_Capacity'].isnull()))
# Out:
# Orignal #missing: 4567
# Final #missing: 0

# %%
from scipy.stats import mode

#Determing the mode for each
IsNewCust_mode = data.pivot_table(values='IsNewCust', columns='Type_Of_Item',aggfunc=lambda x:x.mode())
IsNewCust_mode
# Out:
# Type_Of_Item Baby Products Breakfast Cleaning & HousehOld  \
# IsNewCust              New       New                  New
#
# Type_Of_Item Cleaning & Household Cosemetics Cosmetics Daily Staple  \
# IsNewCust                     New        New       New          New
#
# Type_Of_Item Electronics Fashion Garments Fruits and Vegetables  ...  \
# IsNewCust            New              New                   New  ...
#
# Type_Of_Item Home & Kitchen Leather Goods Others Snack Items Snack items  \
# IsNewCust               New           New    New         New         New
#
# Type_Of_Item Soft Drinks Starchy Foods Toys & Game Products  \
# IsNewCust            New           New                  New
#
# Type_Of_Item Toys & Game products cake item
# IsNewCust                     New       New
#
# [1 rows x 21 columns]

# %%
def impute_size_mode(cols):
    Size = cols[0]
    Type = cols[1]
    if pd.isnull(Size):
        return IsNewCust_mode.loc['IsNewCust'][IsNewCust_mode.columns == Type][0]
    else:
        return Size

print ('Orignal #missing: %d'%sum(data['IsNewCust'].isnull()))
data['IsNewCust'] = data[['IsNewCust','Type_Of_Item']].apply(impute_size_mode,axis=1)
print ('Final #missing: %d'%sum(data['IsNewCust'].isnull()))
# Out:
# Orignal #missing: 1441
# Final #missing: 0

# %%
from scipy.stats import mode

#Determing the mode for each
IsSpecialDay_mode = data.pivot_table(values='IsSpecialDay', columns='Type_Of_Item',aggfunc=lambda x:x.mode())
IsSpecialDay_mode
# Out:
# Type_Of_Item Baby Products Breakfast Cleaning & HousehOld  \
# IsSpecialDay        Diwali    Diwali               Diwali
#
# Type_Of_Item Cleaning & Household Cosemetics Cosmetics Daily Staple  \
# IsSpecialDay               Diwali     Diwali    Diwali       Diwali
#
# Type_Of_Item Electronics Fashion Garments Fruits and Vegetables  ...  \
# IsSpecialDay      Diwali           Diwali                Diwali  ...
#
# Type_Of_Item Home & Kitchen Leather Goods  Others Snack Items Snack items  \
# IsSpecialDay         Diwali        Diwali  Diwali      Diwali      Diwali
#
# Type_Of_Item Soft Drinks Starchy Foods Toys & Game Products  \
# IsSpecialDay      Diwali        Diwali               Diwali
#
# Type_Of_Item Toys & Game products cake item
# IsSpecialDay               Diwali    Diwali
#
# [1 rows x 21 columns]

# %%
def impute_size_mode(cols):
    Size = cols[0]
    Type = cols[1]
    if pd.isnull(Size):
        return IsSpecialDay_mode.loc['IsSpecialDay'][IsSpecialDay_mode.columns == Type][0]
    else:
        return Size

print ('Orignal #missing: %d'%sum(data['IsSpecialDay'].isnull()))
data['IsSpecialDay'] = data[['IsSpecialDay','Type_Of_Item']].apply(impute_size_mode,axis=1)
print ('Final #missing: %d'%sum(data['IsSpecialDay'].isnull()))
# Out:
# Orignal #missing: 60
# Final #missing: 0

# %%
from scipy.stats import mode

#Determing the mode for each
Advertising_Of_Item_mode = data.pivot_table(values='Advertising_Of_Item', columns='Type_Of_Item',aggfunc=lambda x:x.mode())
Advertising_Of_Item_mode
# Out:
# Type_Of_Item        Baby Products Breakfast Cleaning & HousehOld  \
# Advertising_Of_Item           yes       yes                  yes
#
# Type_Of_Item        Cleaning & Household Cosemetics Cosmetics Daily Staple  \
# Advertising_Of_Item                  yes        yes       yes          yes
#
# Type_Of_Item        Electronics Fashion Garments Fruits and Vegetables  ...  \
# Advertising_Of_Item         yes              yes                   yes  ...
#
# Type_Of_Item        Home & Kitchen Leather Goods Others Snack Items  \
# Advertising_Of_Item            yes           yes    yes         yes
#
# Type_Of_Item        Snack items Soft Drinks Starchy Foods  \
# Advertising_Of_Item         yes         yes           yes
#
# Type_Of_Item        Toys & Game Products Toys & Game products cake item
# Advertising_Of_Item                  yes                  yes       yes
#
# [1 rows x 21 columns]

# %%
def impute_size_mode(cols):
    Size = cols[0]
    Type = cols[1]
    if pd.isnull(Size):
        return Advertising_Of_Item_mode.loc['Advertising_Of_Item'][Advertising_Of_Item_mode.columns == Type][0]
    else:
        return Size

print ('Orignal #missing: %d'%sum(data['Advertising_Of_Item'].isnull()))
data['Advertising_Of_Item'] = data[['Advertising_Of_Item','Type_Of_Item']].apply(impute_size_mode,axis=1)
print ('Final #missing: %d'%sum(data['Advertising_Of_Item'].isnull()))
# Out:
# Orignal #missing: 110
# Final #missing: 0

# %%
from scipy.stats import mode

#Determing the mode for each
Population_Density_mode = data.pivot_table(values='Population_Density', columns='Type_Of_Item',aggfunc=lambda x:x.mode())
Population_Density_mode
# Out:
# Type_Of_Item       Baby Products Breakfast Cleaning & HousehOld  \
# Population_Density        Level1    Level1               Level1
#
# Type_Of_Item       Cleaning & Household Cosemetics Cosmetics Daily Staple  \
# Population_Density              Level 1    Level 1    Level1       Level1
#
# Type_Of_Item       Electronics Fashion Garments Fruits and Vegetables  ...  \
# Population_Density     Level 1           Level1                Level1  ...
#
# Type_Of_Item       Home & Kitchen Leather Goods  Others Snack Items  \
# Population_Density         Level1        Level1  Level1     Level 1
#
# Type_Of_Item       Snack items Soft Drinks Starchy Foods Toys & Game Products  \
# Population_Density      Level1      Level1        Level1               Level1
#
# Type_Of_Item       Toys & Game products cake item
# Population_Density              Level 1    Level1
#
# [1 rows x 21 columns]

# %%
def impute_size_mode(cols):
    Size = cols[0]
    Type = cols[1]
    if pd.isnull(Size):
        return Population_Density_mode.loc['Population_Density'][Population_Density_mode.columns == Type][0]
    else:
        return Size

print ('Orignal #missing: %d'%sum(data['Population_Density'].isnull()))
data['Population_Density'] = data[['Population_Density','Type_Of_Item']].apply(impute_size_mode,axis=1)
print ('Final #missing: %d'%sum(data['Population_Density'].isnull()))
# Out:
# Orignal #missing: 1204
# Final #missing: 0

# %%
from scipy.stats import mode

#Determing the mode for each
Discount_Of_Item_mode = data.pivot_table(values='Discount_Of_Item', columns='Type_Of_Item',aggfunc=lambda x:x.mode())
Discount_Of_Item_mode
# Out:
# Type_Of_Item     Baby Products Breakfast Cleaning & HousehOld  \
# Discount_Of_Item           Yes       Yes                  Yes
#
# Type_Of_Item     Cleaning & Household Cosemetics Cosmetics Daily Staple  \
# Discount_Of_Item                   No         No       Yes          Yes
#
# Type_Of_Item     Electronics Fashion Garments Fruits and Vegetables  ...  \
# Discount_Of_Item          No              Yes                   Yes  ...
#
# Type_Of_Item     Home & Kitchen Leather Goods Others Snack Items Snack items  \
# Discount_Of_Item            Yes           Yes    Yes          No         Yes
#
# Type_Of_Item     Soft Drinks Starchy Foods Toys & Game Products  \
# Discount_Of_Item         Yes           Yes                  Yes
#
# Type_Of_Item     Toys & Game products cake item
# Discount_Of_Item                   No       Yes
#
# [1 rows x 21 columns]

# %%
def impute_size_mode(cols):
    Size = cols[0]
    Type = cols[1]
    if pd.isnull(Size):
        return Discount_Of_Item_mode.loc['Discount_Of_Item'][Discount_Of_Item_mode.columns == Type][0]
    else:
        return Size

print ('Orignal #missing: %d'%sum(data['Discount_Of_Item'].isnull()))
data['Discount_Of_Item'] = data[['Discount_Of_Item','Type_Of_Item']].apply(impute_size_mode,axis=1)
print ('Final #missing: %d'%sum(data['Discount_Of_Item'].isnull()))
# Out:
# Orignal #missing: 739
# Final #missing: 0

# %%
data.isnull().sum()
# Out:
# Identifier_Of_Item              0
# Weight_Of_Item                  0
# Content_Of_Fat                  0
# Visibility_Of_Item              0
# Type_Of_Item                    0
# MRP_Of_Item                     0
# Identifier_Of_Outlet            0
# Outlet_Establishment_Year       0
# Store_Capacity                  0
# Outlet_Location_Type            0
# Outlet_Type                     0
# IsNewCust                       0
# IsSpecialDay                    0
# Advertising_Of_Item             0
# Population_Density              0
# Product_Packing                97
# Discount_Of_Item                0
# Item_Outlet_Sales            6681
# source                          0
# dtype: int64

# %%
from scipy.stats import mode

#Determing the mode for each
Product_Packing_mode = data.pivot_table(values='Product_Packing', columns='Type_Of_Item',aggfunc=lambda x:x.mode())
Product_Packing_mode
# Out:
# Type_Of_Item    Baby Products Breakfast Cleaning & HousehOld  \
# Product_Packing          good      good                 good
#
# Type_Of_Item    Cleaning & Household Cosemetics Cosmetics Daily Staple  \
# Product_Packing                 good       good      good         good
#
# Type_Of_Item    Electronics Fashion Garments Fruits and Vegetables  ...  \
# Product_Packing        good             good                  good  ...
#
# Type_Of_Item    Home & Kitchen Leather Goods Others Snack Items Snack items  \
# Product_Packing           good          good   good        good        good
#
# Type_Of_Item    Soft Drinks Starchy Foods Toys & Game Products  \
# Product_Packing        good          good                 good
#
# Type_Of_Item    Toys & Game products cake item
# Product_Packing                 good      good
#
# [1 rows x 21 columns]

# %%
def impute_size_mode(cols):
    Size = cols[0]
    Type = cols[1]
    if pd.isnull(Size):
        return Product_Packing_mode.loc['Product_Packing'][Product_Packing_mode.columns == Type][0]
    else:
        return Size

print ('Orignal #missing: %d'%sum(data['Product_Packing'].isnull()))
data['Product_Packing'] = data[['Product_Packing','Type_Of_Item']].apply(impute_size_mode,axis=1)
print ('Final #missing: %d'%sum(data['Product_Packing'].isnull()))
# Out:
# Orignal #missing: 97
# Final #missing: 0

# %%
data.Item_Outlet_Sales = data.Item_Outlet_Sales.fillna(data.Item_Outlet_Sales.mean())

# %%
data.isnull().sum()
# Out:
# Identifier_Of_Item           0
# Weight_Of_Item               0
# Content_Of_Fat               0
# Visibility_Of_Item           0
# Type_Of_Item                 0
# MRP_Of_Item                  0
# Identifier_Of_Outlet         0
# Outlet_Establishment_Year    0
# Store_Capacity               0
# Outlet_Location_Type         0
# Outlet_Type                  0
# IsNewCust                    0
# IsSpecialDay                 0
# Advertising_Of_Item          0
# Population_Density           0
# Product_Packing              0
# Discount_Of_Item             0
# Item_Outlet_Sales            0
# source                       0
# dtype: int64

# %%
data['Type_Of_Item_Combined'] = data['Identifier_Of_Item'].apply(lambda x: x[0:2])

data['Type_Of_Item_Combined'] = data['Type_Of_Item_Combined'].map({'FD':'Food',
                                                             'NC':'Non-Consumable',
                                                             'DR':'Drinks'})
data['Type_Of_Item_Combined'].value_counts()
# Out:
# Food              11362
# Non-Consumable     3094
# Drinks             1506
# Name: Type_Of_Item_Combined, dtype: int64

# %%
print('Original Categories:')
print(data['Content_Of_Fat'].value_counts())

print('\nModified Categories:')
data['Content_Of_Fat'] = data['Content_Of_Fat'].replace({'LF':'Low Fat',
                                                             'reg':'Regular',
                                                             'low fat':'Low Fat'})

print(data['Content_Of_Fat'].value_counts())
# Out:
# Original Categories:
# Low Fat    9683
# Regular    5499
# LF          598
# reg         222
# low fat     202
# Name: Content_Of_Fat, dtype: int64
#
# Modified Categories:
# Low Fat    10483
# Regular     5721
# Name: Content_Of_Fat, dtype: int64

# %%
data.loc[data['Type_Of_Item_Combined']=="Non-Consumable",'Content_Of_Fat'] = "Non-Edible"
data['Content_Of_Fat'].value_counts()
# Out:
# Low Fat       7389
# Regular       5721
# Non-Edible    3094
# Name: Content_Of_Fat, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16204 entries, 0 to 16203
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Identifier_Of_Item         16204 non-null  object
#  1   Weight_Of_Item             16204 non-null  float64
#  2   Content_Of_Fat             16204 non-null  object
#  3   Visibility_Of_Item         16204 non-null  float64
#  4   Type_Of_Item               16204 non-null  object
#  5   MRP_Of_Item                16204 non-null  float64
#  6   Identifier_Of_Outlet       16204 non-null  object
#  7   Outlet_Establishment_Year  16204 non-null  int64
#  8   Store_Capacity             16204 non-null  object
#  9   Outlet_Location_Type       16204 non-null  object
#  10  Outlet_Type                16204 non-null  object
#  11  IsNewCust                  16204 non-null  object
#  12  IsSpecialDay               16204 non-null  object
# ...

# %%
data.drop(['Type_Of_Item','source'],inplace=True,axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16204 entries, 0 to 16203
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Identifier_Of_Item         16204 non-null  object
#  1   Weight_Of_Item             16204 non-null  float64
#  2   Content_Of_Fat             16204 non-null  object
#  3   Visibility_Of_Item         16204 non-null  float64
#  4   MRP_Of_Item                16204 non-null  float64
#  5   Identifier_Of_Outlet       16204 non-null  object
#  6   Outlet_Establishment_Year  16204 non-null  int64
#  7   Store_Capacity             16204 non-null  object
#  8   Outlet_Location_Type       16204 non-null  object
#  9   Outlet_Type                16204 non-null  object
#  10  IsNewCust                  16204 non-null  object
#  11  IsSpecialDay               16204 non-null  object
#  12  Advertising_Of_Item        16204 non-null  object
# ...

# %%
data.shape
# Out:
# (16204, 18)

# %%
data.isnull().sum()
# Out:
# Identifier_Of_Item             0
# Weight_Of_Item                 0
# Content_Of_Fat                 0
# Visibility_Of_Item             0
# MRP_Of_Item                    0
# Identifier_Of_Outlet           0
# Outlet_Establishment_Year      0
# Store_Capacity                 0
# Outlet_Location_Type           0
# Outlet_Type                    0
# IsNewCust                      0
# IsSpecialDay                   0
# Advertising_Of_Item            0
# Population_Density             0
# Product_Packing                0
# Discount_Of_Item               0
# Item_Outlet_Sales              0
# Type_Of_Item_Combined        242
# dtype: int64

# %%
data = data.dropna()

# %%
dataset=data

# %% [markdown]
# ## Creating a Pipeline

# %%
data = dataset.sample(frac=0.9, random_state=786)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (14366, 18)
# Unseen Data For Predictions: (1596, 18)

# %%
import pycaret

# %%
from pycaret.regression import *

# %%
exp1 = setup(data = data, target = 'Item_Outlet_Sales', session_id=123)
# Out:
# <style  type="text/css" >
# #T_e1627_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_e1627_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1627_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e1627_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e1627_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_e1627_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e1627_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_e1627_row1_col1" class="data row1 col1" >Item_Outlet_Sales</td>
#             </tr>
#             <tr>
# ...

# %%
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# ...

# %%
best_model = compare_models(exclude = ['ransac','tr','huber','mlp','et','svm','kr','par','ard','br','omp','llar','lar','en','rf','lightgbm','knn'])
# Out:
# <style  type="text/css" >
#     #T_24c80_ th {
#           text-align: left;
#     }#T_24c80_row0_col0,#T_24c80_row0_col6,#T_24c80_row1_col0,#T_24c80_row1_col1,#T_24c80_row1_col2,#T_24c80_row1_col3,#T_24c80_row1_col4,#T_24c80_row1_col5,#T_24c80_row1_col6,#T_24c80_row2_col0,#T_24c80_row2_col1,#T_24c80_row2_col2,#T_24c80_row2_col3,#T_24c80_row2_col4,#T_24c80_row2_col5,#T_24c80_row3_col0,#T_24c80_row3_col1,#T_24c80_row3_col2,#T_24c80_row3_col3,#T_24c80_row3_col4,#T_24c80_row3_col5,#T_24c80_row3_col6,#T_24c80_row4_col0,#T_24c80_row4_col1,#T_24c80_row4_col2,#T_24c80_row4_col3,#T_24c80_row4_col4,#T_24c80_row4_col5,#T_24c80_row4_col6,#T_24c80_row5_col0,#T_24c80_row5_col1,#T_24c80_row5_col2,#T_24c80_row5_col3,#T_24c80_row5_col4,#T_24c80_row5_col5,#T_24c80_row5_col6,#T_24c80_row6_col0,#T_24c80_row6_col1,#T_24c80_row6_col2,#T_24c80_row6_col3,#T_24c80_row6_col4,#T_24c80_row6_col5,#T_24c80_row6_col6{
#             text-align:  left;
#             text-align:  left;
# ...

# %%
best_model
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=123, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='auto',
#              validate_parameters=1, verbosity=0)

# %%
xgboost = create_model('xgboost')
# Out:
# <style  type="text/css" >
# #T_81480_row10_col0,#T_81480_row10_col1,#T_81480_row10_col2,#T_81480_row10_col3,#T_81480_row10_col4,#T_81480_row10_col5{
#             background:  yellow;
#         }</style><table id="T_81480_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_81480_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_81480_row0_col0" class="data row0 col0" >445.2283</td>
#                         <td id="T_81480_row0_col1" class="data row0 col1" >607065.4375</td>
# ...

# %%
tuned_sciopt = tune_model(xgboost, search_library = 'scikit-optimize')
# Out:
# <style  type="text/css" >
# #T_997b5_row10_col0,#T_997b5_row10_col1,#T_997b5_row10_col2,#T_997b5_row10_col3,#T_997b5_row10_col4,#T_997b5_row10_col5{
#             background:  yellow;
#         }</style><table id="T_997b5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_997b5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_997b5_row0_col0" class="data row0 col0" >421.9889</td>
#                         <td id="T_997b5_row0_col1" class="data row0 col1" >570914.6250</td>
# ...

# %%
print(tuned_sciopt)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.9962590536997258, gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints='',
#              learning_rate=0.02232625052729537, max_delta_step=0, max_depth=9,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=153, n_jobs=-1, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=123,
#              reg_alpha=1.008430031524327e-08, reg_lambda=0.0005714018386876504,
#              scale_pos_weight=3.8013713546631984, subsample=0.8980414500809213,
#              tree_method='auto', validate_parameters=1, verbosity=0)

# %%
save_model(tuned_sciopt,'deployement')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='Item_Outlet_Sales',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeri...
#                                max_delta_step=0, max_depth=9, min_child_weight=1,
#                                missing=nan, monotone_constraints='()',
# ...

# %%
deployement = load_model('deployement')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
deployement
# Out:
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[],
#                                       target='Item_Outlet_Sales',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeri...
#                               max_delta_step=0, max_depth=9, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=153, n_jobs=-1, num_parallel_tree=1,
# ...

# %%
data_unseen.drop(['Item_Outlet_Sales'],inplace=True,axis=1)

# %%
unseen_predictions = predict_model(deployement, data=data_unseen)
unseen_predictions.head()
# Out:
#   Identifier_Of_Item  Weight_Of_Item Content_Of_Fat  Visibility_Of_Item  \
# 0              FDP36          10.395        Regular            0.000000
# 1              DRI11           8.260        Low Fat            0.034238
# 2              DRZ11           8.850        Regular            0.113124
# 3              FDB34          15.250        Low Fat            0.026481
# 4              DRK35           8.365        Low Fat            0.071958
#
#    MRP_Of_Item Identifier_Of_Outlet  Outlet_Establishment_Year Store_Capacity  \
# 0      51.4008               OUT018                       2009         Medium
# 1     113.2834               OUT027                       2010         Medium
# 2     122.5388               OUT018                       2009         Medium
# 3      87.6198               OUT027                       2010         Medium
# 4      38.0506               OUT049                       2019         Medium
#
# ...

# %%
unseen_predictions.head(50)
# Out:
#    Identifier_Of_Item  Weight_Of_Item Content_Of_Fat  Visibility_Of_Item  \
# 0               FDP36          10.395        Regular            0.000000
# 1               DRI11           8.260        Low Fat            0.034238
# 2               DRZ11           8.850        Regular            0.113124
# 3               FDB34          15.250        Low Fat            0.026481
# 4               DRK35           8.365        Low Fat            0.071958
# 5               FDY45          17.500        Low Fat            0.026016
# 6               FDH35          18.250        Low Fat            0.000000
# 7               NCL18          18.850     Non-Edible            0.293418
# 8               FDA44          19.700        Low Fat            0.053213
# 9               FDU04           7.930        Low Fat            0.009715
# 10              FDF41          12.150        Low Fat            0.131384
# 11              FDH14          17.100        Regular            0.046770
# ...

# %%
unseen_predictions.tail(50)
# Out:
#      Identifier_Of_Item  Weight_Of_Item Content_Of_Fat  Visibility_Of_Item  \
# 1546              FDK33          17.850        Low Fat            0.018806
# 1547              NCZ05           8.485     Non-Edible            0.058250
# 1548              FDP24          20.600        Low Fat            0.083342
# 1549              FDX46          12.300        Regular            0.101755
# 1550              FDE38           6.520        Low Fat            0.044789
# 1551              FDF08          14.300        Regular            0.114170
# 1552              FDE39           7.890        Low Fat            0.036339
# 1553              FDS25           6.885        Regular            0.140226
# 1554              FDI10           8.510        Regular            0.078724
# 1555              FDU35           6.440        Low Fat            0.079200
# 1556              DRL11          10.500        Low Fat            0.080373
# ...
